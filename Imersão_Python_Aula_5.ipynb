# %% [markdown]
# <a href="https://colab.research.google.com/github/ClaudiaSantosSilva/Imers-o_Python_Alura/blob/main/Imers%C3%A3o_Python_Aula_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pystan==2.19.1.1
# Out:
# ...
#   Using cached pystan-2.19.1.1.tar.gz (16.2 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pystan: filename=pystan-2.19.1.1-cp310-cp310-linux_x86_64.whl size=61975254 sha256=d1ab8df8924be01a4508fffb54d9d3746428f14688accfd095d26c741f6a80aa
#   Stored in directory: /root/.cache/pip/wheels/3d/1c/94/4516243362eedbedad15ac4389691ee3bf2d45bec2639c9d8b
# Successfully built pystan
# ...

# %%
pip install prophet

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from prophet import Prophet

# %%
dados=yf.download("JNJ", start='2020-01-01', end='2023-12-31', progress=False)
dados=dados.reset_index()
dados
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-01-02  145.869995  146.020004  145.080002  145.970001  130.099106
# 1    2020-01-03  143.500000  145.369995  143.000000  144.279999  128.592880
# 2    2020-01-06  144.000000  144.199997  142.850006  144.100006  128.432434
# 3    2020-01-07  144.009995  145.449997  141.380005  144.979996  129.216751
# 4    2020-01-08  144.869995  145.979996  143.699997  144.960007  129.198929
# ...         ...         ...         ...         ...         ...         ...
# 1001 2023-12-22  155.250000  156.529999  155.020004  155.460007  154.288544
# 1002 2023-12-26  155.000000  156.350006  154.850006  156.139999  154.963409
# 1003 2023-12-27  155.500000  156.520004  155.419998  156.350006  155.171844
# 1004 2023-12-28  156.000000  157.240005  155.990005  156.580002  155.400101
# 1005 2023-12-29  156.509995  156.899994  155.979996  156.740005  155.558899
#
#        Volume
# 0     5777000
# 1     5752400
# ...

# %%
dados_treino=dados[dados['Date'] < '2023-07-31']
dados_teste= dados[dados['Date'] >= '2023-07-31']

# %%
dados_prophet_treino = dados_treino[['Date', 'Close']].rename(columns={'Date': 'ds', 'Close':'y'})
dados_prophet_treino
# Out:
#             ds           y
# 0   2020-01-02  145.970001
# 1   2020-01-03  144.279999
# 2   2020-01-06  144.100006
# 3   2020-01-07  144.979996
# 4   2020-01-08  144.960007
# ..         ...         ...
# 894 2023-07-24  171.080002
# 895 2023-07-25  172.389999
# 896 2023-07-26  172.720001
# 897 2023-07-27  173.690002
# 898 2023-07-28  174.479996
#
# [899 rows x 2 columns]

# %%
modelo = Prophet(weekly_seasonality=True,
                  yearly_seasonality=True,
                  daily_seasonality=False)

modelo.add_country_holidays(country_name='US')

modelo.fit(dados_prophet_treino)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp43ul_sm0/jska4gm8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp43ul_sm0/1c9xzgf1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13106', 'data', 'file=/tmp/tmp43ul_sm0/jska4gm8.json', 'init=/tmp/tmp43ul_sm0/1c9xzgf1.json', 'output', 'file=/tmp/tmp43ul_sm0/prophet_modelw5tgl5z6/prophet_model-20240403212905.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 21:29:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 21:29:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
futuro=modelo.make_future_dataframe(periods=150)
previsao=modelo.predict(futuro)

# %%
plt.figure(figsize=(14, 8))
plt.plot(dados_treino['Date'], dados_treino['Close'], label='Dados de Treino', color='blue')
plt.plot(dados_teste['Date'], dados_teste['Close'], label='Dados Reais (teste)', color='green')
plt.plot(previsao['ds'], previsao['yhat'], label='Previsão', color='orange', linestyle='--')

plt.axvline(dados_treino['Date'].max(), color='red', linestyle='--', label='Início da Previsão')
plt.xlabel ('Data')
plt.ylabel ('Preço de fechamento')
plt.title ('Previsão de preço de fechamento vs Dados reais')
plt.legend()
plt.show()
